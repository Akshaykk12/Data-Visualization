# %%
import matplotlib.pyplot as plt

# %%
data = [12, 34, 1, 56, 33, 11, 15, 67]

# %%
data
# Out:
# [12, 34, 1, 56, 33, 11, 15, 67]

# %%
plt.plot(data)

# %%
over= [1, 2, 3, 4, 5]
runs= [1, 7, 13, 18, 20]

# %%
plt.plot(over, runs)

# %%
states= ["Goa", "Maharashtra", "Kerala", "Andhra"]
count=[1200, 450, 900, 1100]

# %%
plt.bar(states, count, width=0.4)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(states,count,label="Year 2000")
plt.bar(states,[500,200,350,400],label="Year 2021")
plt.legend()

# %%
import numpy as np

# %%
y=np.random.random(25)

# %%
y
# Out:
# array([0.94467046, 0.99442579, 0.31992707, 0.1053163 , 0.25242571,
#        0.78326756, 0.82377592, 0.7433932 , 0.63157129, 0.70399959,
#        0.12948207, 0.75243948, 0.37504638, 0.07589119, 0.29837888,
#        0.49821436, 0.85241303, 0.46965356, 0.48406669, 0.49630025,
#        0.15852628, 0.46724   , 0.79587805, 0.50423911, 0.0563606 ])

# %%
x=range(25)

# %%
x
# Out:
# range(0, 25)

# %%
plt.scatter(x,y)

# %%
percentage=[56,28,90,67,88,91,92,45,55,57,50,66,69,40,50,66,88]

# %%
percentage
# Out:
# [56, 28, 90, 67, 88, 91, 92, 45, 55, 57, 50, 66, 69, 40, 50, 66, 88]

# %%
plt.hist(percentage,range=(45,76),bins=5,cumulative=True,histtype='step')
# Out:
# (array([ 3.,  6.,  6., 10., 10.]),
#  array([45. , 51.2, 57.4, 63.6, 69.8, 76. ]),
#  [<matplotlib.patches.Polygon at 0x2ae369d78b0>])

# %%
company=['infosys','IBM','Zensar','wipro']
shares=[60,55,65,70]

# %%
plt.pie(shares,autopct='%.f%%',labels=company,radius=1.4,labeldistance=0.7,explode=[0,0,0,0.1])
plt.show()

# %%
plt.subplots(2,2)
plt.tight_layout()

# %%
a=[10,20,30,40,50]
b=[100,200,300,400,500]

# %%
plt.figure(figsize=(12,3))

plt.subplot(221)
plt.bar(a,b)

plt.subplot(222)
plt.plot(a,b)

plt.subplot(223)
plt.scatter(a,b)

plt.subplot(224)
plt.plot(a,b)

# %%
import pandas as pd

# %%
data=np.random.random((5,4))

# %%
data
# Out:
# array([[0.57686515, 0.11697314, 0.95382634, 0.33206755],
#        [0.03363255, 0.20853616, 0.36828571, 0.43573022],
#        [0.29782545, 0.60978735, 0.26486374, 0.09988164],
#        [0.82615734, 0.75840263, 0.48508766, 0.98997956],
#        [0.95013825, 0.22705267, 0.191413  , 0.95437008]])

# %%
df=pd.DataFrame(data,columns=list('abcd'))

# %%
df
# Out:
#           a         b         c         d
# 0  0.576865  0.116973  0.953826  0.332068
# 1  0.033633  0.208536  0.368286  0.435730
# 2  0.297825  0.609787  0.264864  0.099882
# 3  0.826157  0.758403  0.485088  0.989980
# 4  0.950138  0.227053  0.191413  0.954370

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
df[['a','b']].plot()
# Out:
# <AxesSubplot: >

# %%
df.plot(x='a',kind='bar')
# Out:
# <AxesSubplot: xlabel='a'>

# %%
df.plot(x='a',y='b',kind='bar')
# Out:
# <AxesSubplot: xlabel='a'>

# %%
df['cat']=["aa","bb", "cc", "dd", "ee"]

# %%
df
# Out:
#           a         b         c         d cat
# 0  0.576865  0.116973  0.953826  0.332068  aa
# 1  0.033633  0.208536  0.368286  0.435730  bb
# 2  0.297825  0.609787  0.264864  0.099882  cc
# 3  0.826157  0.758403  0.485088  0.989980  dd
# 4  0.950138  0.227053  0.191413  0.954370  ee

# %%
df['a'].plot()
# Out:
# <AxesSubplot: >
